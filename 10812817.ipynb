# %%
import tweepy, re
from textblob import TextBlob
import matplotlib.pyplot as plt
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
import snscrape.modules.twitter as sntwitter
import itertools

# %%
consumerKey = 'vkR4EPCv7R2799HRBmfOA4TFx'
consumerSecret = 'Df1saFchn0c8u9e0L54L8GzkhM8MYFTH0xpqH7GZJpON6JNpJv'
accessToken = '1095786972512223233-hkeJByEIeugwUczVTEHTLpWjXzGAZ2'
accessTokensecret='Wdagfmrt89u6TIQhZr0WKfTo4TP6pY9xLEXXHMQTgryk5'
auth = tweepy.OAuthHandler(consumerKey, consumerSecret)
auth.set_access_token(accessToken, accessTokensecret)
api = tweepy.API(auth)

# %%
topic=input('Please input topic you want to analyze ')
num_tweet= int(input("How many tweets do you want to analye? "))
a = input('Lets know the region you want to use "PLEASE ENTER THE NAME OF A CITY" ')
locat = '"' + a + '"'
tweet_df = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    topic+ ' near:'+locat + " within:30km").get_items(), num_tweet))
# Out:
# Please input topic you want to analyze Accra
# How many tweets do you want to analye? 100
# Lets know the region you want to use "PLEASE ENTER THE NAME OF A CITY" Accra

# %%
tweet_df.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/amuxeen/status/15590983423...
# 1  https://twitter.com/glovben/status/15590976522...
# 2  https://twitter.com/TabMij/status/155909717302...
# 3  https://twitter.com/tomas_adu/status/155909693...
# 4  https://twitter.com/enochdela88/status/1559096...
#
#                        date  \
# 0 2022-08-15 08:43:06+00:00
# 1 2022-08-15 08:40:21+00:00
# 2 2022-08-15 08:38:27+00:00
# 3 2022-08-15 08:37:30+00:00
# 4 2022-08-15 08:37:28+00:00
#
#                                           rawContent  \
# 0  [Trending]\nAlready, the fast rising rapper ha...
# 1               @jamessowah Accra is the new Ankara.
# 2                                  Accra needs this.
# 3          Accra life hmmm 🤔 https://t.co/ez00HpvwEe
# 4  If transport fares in Accra doesn’t finish you...
#
#                                      renderedContent                   id  \
# ...

# %%
tweet_df.to_csv('tweet_df.csv')

# %%
tweet_df.isnull().sum()
# Out:
# url                   0
# date                  0
# rawContent            0
# renderedContent       0
# id                    0
# user                  0
# replyCount            0
# retweetCount          0
# likeCount             0
# quoteCount            0
# conversationId        0
# lang                  0
# source                0
# sourceUrl             0
# sourceLabel           0
# links                66
# media                82
# retweetedTweet      100
# quotedTweet          94
# inReplyToTweetId     66
# inReplyToUser        66
# mentionedUsers       62
# coordinates          78
# place                78
# hashtags             76
# cashtags            100
# card                 71
# dtype: int64

# %%
tweet_df.isnull().sum().sum()
# Out:
# 939
